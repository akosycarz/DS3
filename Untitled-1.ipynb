# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#reading the data into panda dataframe
data = pd.read_csv('/Users/ania/Desktop/data_science/ass3/recruitmentdataset-2022-1.3.csv')
df = pd.DataFrame(data)
df
# Out:
#           Id  gender  age nationality     sport  ind-university_grade  \
# 0     x8011e  female   24      German  Swimming                    70
# 1     x6077a    male   26      German      Golf                    67
# 2     x6006e  female   23       Dutch   Running                    67
# 3     x2173b    male   24       Dutch   Cricket                    70
# 4     x6241a  female   26      German      Golf                    59
# ...      ...     ...  ...         ...       ...                   ...
# 3995  x7640e  female   28       Dutch   Running                    63
# 3996  x3310f  female   27       Dutch    Tennis                    62
# 3997  x1202g    male   24     Belgian     Rugby                    60
# 3998  x1263d  female   22       Dutch    Tennis                    66
# 3999  x2396a    male   28       Dutch  Football                    58
#
#       ind-debateclub  ind-programming_exp  ind-international_exp  \
# ...

# %%
#Describe the data
df.head()
# Out:
#        Id  gender  age nationality     sport  ind-university_grade  \
# 0  x8011e  female   24      German  Swimming                    70
# 1  x6077a    male   26      German      Golf                    67
# 2  x6006e  female   23       Dutch   Running                    67
# 3  x2173b    male   24       Dutch   Cricket                    70
# 4  x6241a  female   26      German      Golf                    59
#
#    ind-debateclub  ind-programming_exp  ind-international_exp  \
# 0           False                False                  False
# 1           False                 True                  False
# 2           False                 True                   True
# 3           False                 True                  False
# 4           False                False                  False
#
#    ind-entrepeneur_exp  ind-languages  ind-exact_study ind-degree company  \
# 0                False              1             True        phd       A
# ...

# %%
df.shape
# Out:
# (4000, 15)

# %%
df.describe()
# Out:
#                age  ind-university_grade  ind-languages
# count  4000.000000           4000.000000    4000.000000
# mean     26.179000             62.380000       1.336250
# std       2.807477              5.916194       0.854031
# min      21.000000             45.000000       0.000000
# 25%      24.000000             58.000000       1.000000
# 50%      26.000000             62.000000       1.000000
# 75%      28.000000             67.000000       2.000000
# max      32.000000             78.000000       3.000000

# %%
df.value_counts()
# Out:
# Id      gender  age  nationality  sport     ind-university_grade  ind-debateclub  ind-programming_exp  ind-international_exp  ind-entrepeneur_exp  ind-languages  ind-exact_study  ind-degree  company  decision
# x1002f  male    29   Dutch        Swimming  66                    True            False                False                  True                 3              False            master      B        True        1
# x7012e  male    27   Dutch        Tennis    62                    True            False                True                   False                2              False            phd         B        True        1
# x6983c  male    26   German       Football  68                    False           True                 False                  False                1              True             bachelor    C        False       1
# ...

# %%
df.columns
# Out:
# Index(['Id', 'gender', 'age', 'nationality', 'sport', 'ind-university_grade',
#        'ind-debateclub', 'ind-programming_exp', 'ind-international_exp',
#        'ind-entrepeneur_exp', 'ind-languages', 'ind-exact_study', 'ind-degree',
#        'company', 'decision'],
#       dtype='object')

# %% [markdown]
# explore the data

# %%
# Create a dictionary to map sports to unique markers
sports_markers = {
    'Sport1': 'o',  # Use 'o' for circles
    'Sport2': 's',  # Use 's' for squares
    'Sport3': '^',  # Use '^' for triangles
    'Sport4': 'D',  # Use 'D' for diamonds
    # Add more sports and corresponding markers as needed
}

# Scatterplot of Age vs. Scores with different markers for sports
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='age', y='ind-university_grade', hue='sport', style='sport', palette='Set1')
plt.title('Scatterplot of Age vs. University Grade by Gender and Sport')
plt.xlabel('Age')
plt.ylabel('University Grade')
plt.legend(title='Gender')
plt.show()

# %%
# Histogram of Age
plt.figure(figsize=(8, 6))
sns.histplot(df['age'], bins=20, kde=True)
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Violin Plot of University Grade by Gender
plt.figure(figsize=(8, 6))
sns.violinplot(data=df, x='gender', y='ind-university_grade', palette='Pastel1')
plt.title('Violin Plot of University Grade by Gender')
plt.xlabel('Gender')
plt.ylabel('University Grade')
plt.show()

# %%
# Calculate the hiring probability for each combination of age, degree, and gender
hiring_probabilities_age_degree_gender = df.groupby(['age', 'ind-degree', 'gender'])['decision'].mean().reset_index()

# Calculate the hiring probability for each combination of age and programming experience
hiring_probabilities_age_programming = df.groupby(['age', 'ind-programming_exp'])['decision'].mean().unstack()

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

# Plot the first bar chart (Age, Degree, Gender)
sns.barplot(data=hiring_probabilities_age_degree_gender, x='age', y='decision', hue='gender', ci=None, ax=axes[0])
axes[0].set_title('Probability of Being Hired by Age, Degree, and Gender')
axes[0].set_xlabel('Age')
axes[0].set_ylabel('Probability of Being Hired')
axes[0].legend(title='Gender')
axes[0].tick_params(axis='x', rotation=45)

#second bar chart (Age, Programming Experience)
hiring_probabilities_age_programming.plot(kind='bar', ax=axes[1], stacked=True)
axes[1].set_title('Probability of Being Hired by Age and Programming Experience')
axes[1].set_xlabel('Age')
axes[1].set_ylabel('Probability of Being Hired')
axes[1].legend(title='Programming Experience')
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/yf/ng81hzj90134sv_mlqz937qc0000gn/T/ipykernel_69239/2042623786.py:11: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=hiring_probabilities_age_degree_gender, x='age', y='decision', hue='gender', ci=None, ax=axes[0])
